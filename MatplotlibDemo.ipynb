# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
yas=[10,20,30]
kilo=[40,50,60]

# %%
yas1=np.array(yas)
kilo1=np.array(kilo)

# %%
plt.plot(yas1,kilo1)

# %%
dizi=np.linspace(0,10,20)

# %%
dizi1=dizi**3

# %%
plt.plot(dizi,dizi1)

# %%
yeniFigure=plt.figure()

# %%
yeniEksen=yeniFigure.add_axes([0.1,0.1,0.9,0.9])
yeniEksen.plot(dizi,dizi**2,label="1.grafik")
yeniEksen.plot(dizi,dizi**3,label="2.grafik")
yeniEksen.legend()

# %%
graf1
